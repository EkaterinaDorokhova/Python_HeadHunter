# %% [markdown]
# <center> <img src = https://raw.githubusercontent.com/AndreyRysistov/DatasetsForPandas/main/hh%20label.jpg alt="drawing" style="width:400px;">

# %% [markdown]
# # <center> Проект: Анализ резюме из HeadHunter

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %% [markdown]
# # Исследование структуры данных

# %% [markdown]
# 1. Прочитайте данные с помощью библиотеки Pandas. Совет: перед чтением обратите внимание на разделитель внутри файла.

# %%
#ваш код здесь

from google.colab import drive
drive.mount('/content/drive')

df = pd.read_csv('/content/drive/MyDrive/Studies/dst-3.0_16_1_hh_database.csv', sep=';')
# Out:
# Mounted at /content/drive

# %% [markdown]
# 2. Выведите несколько первых (последних) строк таблицы, чтобы убедиться в том, что ваши данные не повреждены. Ознакомьтесь с признаками и их структурой.

# %%
#ваш код здесь

df.head()
# Out:
#                                    Пол, возраст           ЗП  \
# 0    Мужчина ,  39 лет , родился 27 ноября 1979   29000 руб.
# 1     Мужчина ,  60 лет , родился 20 марта 1959   40000 руб.
# 2  Женщина ,  36 лет , родилась 12 августа 1982   20000 руб.
# 3      Мужчина ,  38 лет , родился 25 июня 1980  100000 руб.
# 4     Женщина ,  26 лет , родилась 3 марта 1993  140000 руб.
#
#                            Ищет работу на должность:  \
# 0                            Системный администратор
# 1                               Технический писатель
# 2                                           Оператор
# 3  Веб-разработчик (HTML / CSS / JS / PHP / базы ...
# 4                  Региональный менеджер по продажам
#
#                         Город, переезд, командировки  \
# 0  Советск (Калининградская область) , не готов к...
# 1  Королев , не готов к переезду , готов к редким...
# 2  Тверь , не готова к переезду , не готова к ком...
# 3  Саратов , не готов к переезду , готов к редким...
# ...

# %% [markdown]
# 3. Выведите основную информацию о числе непустых значений в столбцах и их типах в таблице.

# %% [markdown]
# 4. Обратите внимание на информацию о числе непустых значений.

# %%
#ваш код здесь

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44744 entries, 0 to 44743
# Data columns (total 12 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Пол, возраст                     44744 non-null  object
#  1   ЗП                               44744 non-null  object
#  2   Ищет работу на должность:        44744 non-null  object
#  3   Город, переезд, командировки     44744 non-null  object
#  4   Занятость                        44744 non-null  object
#  5   График                           44744 non-null  object
#  6   Опыт работы                      44576 non-null  object
#  7   Последнее/нынешнее место работы  44743 non-null  object
#  8   Последняя/нынешняя должность     44742 non-null  object
#  9   Образование и ВУЗ                44744 non-null  object
#  10  Обновление резюме                44744 non-null  object
#  11  Авто                             44744 non-null  object
# ...

# %% [markdown]
# 5. Выведите основную статистическую информацию о столбцах.

# %%
#ваш код здесь

df.describe()
# Out:
#                                          Пол, возраст          ЗП  \
# count                                           44744       44744
# unique                                          16003         690
# top     Мужчина ,  32 года , родился 17 сентября 1986  50000 руб.
# freq                                               18        4064
#
#        Ищет работу на должность:  \
# count                      44744
# unique                     14929
# top      Системный администратор
# freq                        3099
#
#                              Город, переезд, командировки         Занятость  \
# count                                               44744             44744
# unique                                              10063                38
# top     Москва , не готов к переезду , не готов к кома...  полная занятость
# freq                                                 1261             30026
#
#              График                                        Опыт работы  \
# ...

# %% [markdown]
# # Преобразование данных

# %% [markdown]
# 1. Начнем с простого - с признака **"Образование и ВУЗ"**. Его текущий формат это: **<Уровень образования год выпуска ВУЗ специальность...>**. Например:
# * Высшее образование 2016 Московский авиационный институт (национальный исследовательский университет)...
# * Неоконченное высшее образование 2000  Балтийская государственная академия рыбопромыслового флота…
# Нас будет интересовать только уровень образования.
#
# Создайте с помощью функции-преобразования новый признак **"Образование"**, который должен иметь 4 категории: "высшее", "неоконченное высшее", "среднее специальное" и "среднее".
#
# Выполните преобразование, ответьте на контрольные вопросы и удалите признак "Образование и ВУЗ".
#
# Совет: обратите внимание на структуру текста в столбце **"Образование и ВУЗ"**. Гарантируется, что текущий уровень образования соискателя всегда находится в первых 2ух слов и начинается с заглавной буквы. Воспользуйтесь этим.
#
# *Совет: проверяйте полученные категории, например, с помощью метода unique()*

# %%
#ваш код здесь

# Уровнень образования
def extract_education(text):
    if pd.isna(text):  # Пропуски
        return None
    text = text.lower().strip()  # Всё в нижний регистр, убираем лишние пробелы, если они есть
    # Проверяем ключевые слова
    if text.startswith('высшее'):
        return 'высшее'
    elif text.startswith('неоконченное высшее'):
        return 'неоконченное высшее'
    elif text.startswith('среднее специальное'):
        return 'среднее специальное'
    elif text.startswith('среднее'):
        return 'среднее'
    return 'не указано'

# Пропусков до преобразования
print("Пропуски в столбце 'Образование и ВУЗ' до преобразования:", df['Образование и ВУЗ'].isna().sum())

# Примененеие функции
df['Образование'] = df['Образование и ВУЗ'].apply(extract_education)

# Проверка нового столбца
print(df[['Образование', 'Образование и ВУЗ']].head())

# Уникальных значений и пропусков после преобразования.
print("Уникальные значения в столбце 'Образование':", df['Образование'].unique())

print("Пропуски в столбце 'Образование' после преобразования:", df['Образование'].isna().sum())
# Out:
# Пропуски в столбце 'Образование и ВУЗ' до преобразования: 0
#            Образование                                  Образование и ВУЗ
# 0  неоконченное высшее  Неоконченное высшее образование 2000  Балтийск...
# 1               высшее  Высшее образование 1981  Военно-космическая ак...
# 2  среднее специальное  Среднее специальное образование 2002 Профессио...
# 3               высшее  Высшее образование 2002  Саратовский государст...
# 4               высшее  Высшее образование 2015 Кгу Психологии и педаг...
# Уникальные значения в столбце 'Образование': ['неоконченное высшее' 'высшее' 'среднее специальное' 'среднее']
# Пропуски в столбце 'Образование' после преобразования: 0

# %% [markdown]
# 2. Теперь нас интересует столбец **"Пол, возраст"**. Сейчас он представлен в формате **<Пол , возраст , дата рождения >**. Например:
# * Мужчина , 39 лет , родился 27 ноября 1979
# * Женщина , 21 год , родилась 13 января 2000
# Как вы понимаете, нам необходимо выделить каждый параметр в отдельный столбец.
#
# Создайте два новых признака **"Пол"** и **"Возраст"**. При этом важно учесть:
# * Признак пола должен иметь 2 уникальных строковых значения: 'М' - мужчина, 'Ж' - женщина.
# * Признак возраста должен быть представлен целыми числами.
#
# Выполните преобразование, ответьте на контрольные вопросы и удалите признак **"Пол, возраст"** из таблицы.
#
# *Совет: обратите внимание на структуру текста в столбце, в части на то, как разделены параметры пола, возраста и даты рождения между собой - символом ' , '.
# Гарантируется, что структура одинакова для всех строк в таблице. Вы можете воспользоваться этим.*

# %%
#ваш код здесь

# Извлечение пола
def extract_gender(text):
    if 'мужчина' in text.lower():
        return 'М'
    elif 'женщина' in text.lower():
        return 'Ж'
    return None  # None, если данных нет

# Извлечение возраста
def extract_age(text):
    try:
        return int(text.split(',')[1].split()[0])  # Берём вторую часть, первое число
    except (IndexError, ValueError):
        return None  # None, если что-то не так

df['Пол'] = df['Пол, возраст'].apply(extract_gender)
df['Возраст'] = df['Пол, возраст'].apply(extract_age)

print("Первые строки с новыми признаками:")
print(df[['Пол', 'Возраст', 'Пол, возраст']].head())

# Проверка
print("Уникальные значения в столбце 'Пол':", df['Пол'].unique())
print("Статистика возраста:")
print(df['Возраст'].describe())

# Удаление исходного "Пол, возраст"
df = df.drop(columns=['Пол, возраст'])

# Проверка результата
print("Столбцы таблицы после удаления 'Пол, возраст':")
print(df.columns)
df.head()
# Out:
# Первые строки с новыми признаками:
#   Пол  Возраст                                  Пол, возраст
# 0   М       39    Мужчина ,  39 лет , родился 27 ноября 1979
# 1   М       60     Мужчина ,  60 лет , родился 20 марта 1959
# 2   Ж       36  Женщина ,  36 лет , родилась 12 августа 1982
# 3   М       38      Мужчина ,  38 лет , родился 25 июня 1980
# 4   Ж       26     Женщина ,  26 лет , родилась 3 марта 1993
# Уникальные значения в столбце 'Пол': ['М' 'Ж']
# Статистика возраста:
# count    44744.000000
# mean        32.196741
# std          7.929800
# min         14.000000
# 25%         27.000000
# 50%         31.000000
# 75%         36.000000
# max        100.000000
# Name: Возраст, dtype: float64
# Столбцы таблицы после удаления 'Пол, возраст':
# Index(['ЗП', 'Ищет работу на должность:', 'Город, переезд, командировки',
#        'Занятость', 'График', 'Опыт работы', 'Последнее/нынешнее место работы',
#        'Последняя/нынешняя должность', 'Образование и ВУЗ',
# ...

# %% [markdown]
# 3. Следующим этапом преобразуем признак **"Опыт работы"**. Его текущий формат - это: **<Опыт работы: n лет m месяцев, периоды работы в различных компаниях…>**.
#
# Из столбца нам необходимо выделить общий опыт работы соискателя в месяцах, новый признак назовем "Опыт работы (месяц)"
#
# Для начала обсудим условия решения задачи:
# * Во-первых, в данном признаке есть пропуски. Условимся, что если мы встречаем пропуск, оставляем его как есть (функция-преобразование возвращает NaN)
# * Во-вторых, в данном признаке есть скрытые пропуски. Для некоторых соискателей в столбце стоит значения "Не указано". Их тоже обозначим как NaN (функция-преобразование возвращает NaN)
# * В-третьих, нас не интересует информация, которая описывается после указания опыта работы (периоды работы в различных компаниях)
# * В-четвертых, у нас есть проблема: опыт работы может быть представлен только в годах или только месяцах. Например, можно встретить следующие варианты:
#     * Опыт работы 3 года 2 месяца…
#     * Опыт работы 4 года…
#     * Опыт работы 11 месяцев…
#     * Учитывайте эту особенность в вашем коде
#
# Учитывайте эту особенность в вашем коде
#
# В результате преобразования у вас должен получиться столбец, содержащий информацию о том, сколько месяцев проработал соискатель.
# Выполните преобразование, ответьте на контрольные вопросы и удалите столбец **"Опыт работы"** из таблицы.

# %%
#ваш код здесь

def convert_experience(text):
    if pd.isna(text) or 'не указано' in text.lower(): # Пропуски и "Не указано"
        return None

    years = 0
    months = 0
    parts = text.split()  # Строку на части

    for i, part in enumerate(parts):
        if part.isdigit():  # Проверка на число
            # Проверка конца списка
            if i + 1 < len(parts):
                # Конвертация в числа и счёт месяцев
                if 'год' in parts[i + 1] or 'года' in parts[i + 1] or 'лет' in parts[i + 1]:
                    years = int(part)
                elif 'месяц' in parts[i + 1] or 'месяца' in parts[i + 1] or 'месяцев' in parts[i + 1]:
                    months = int(part)

    return years * 12 + months

df['Опыт работы (месяц)'] = df['Опыт работы'].apply(convert_experience)

# Удаление исходного "Опыт работы"
df = df.drop(columns=['Опыт работы'])

# Результат
print("Опыт работы в месяцах (статистика):")
print(df['Опыт работы (месяц)'].describe())
print(df.columns)
df.head()
# Out:
# Опыт работы в месяцах (статистика):
# count    44568.000000
# mean       361.184751
# std       2761.182199
# min          1.000000
# 25%         19.000000
# 50%         31.000000
# 75%         58.000000
# max      96005.000000
# Name: Опыт работы (месяц), dtype: float64
# Index(['ЗП', 'Ищет работу на должность:', 'Город, переезд, командировки',
#        'Занятость', 'График', 'Последнее/нынешнее место работы',
#        'Последняя/нынешняя должность', 'Образование и ВУЗ',
#        'Обновление резюме', 'Авто', 'Образование', 'Пол', 'Возраст',
#        'Опыт работы (месяц)'],
#       dtype='object')
#             ЗП                          Ищет работу на должность:  \
# 0   29000 руб.                            Системный администратор
# 1   40000 руб.                               Технический писатель
# 2   20000 руб.                                           Оператор
# 3  100000 руб.  Веб-разработчик (HTML / CSS / JS / PHP / базы ...
# ...

# %% [markdown]
# 4. Хорошо идем! Следующий на очереди признак "Город, переезд, командировки". Информация в нем представлена в следующем виде: **<Город , (метро) , готовность к переезду (города для переезда) , готовность к командировкам>**. В скобках указаны необязательные параметры строки. Например, можно встретить следующие варианты:
#
# * Москва , не готов к переезду , готов к командировкам
# * Москва , м. Беломорская , не готов к переезду, не готов к командировкам
# * Воронеж , готов к переезду (Сочи, Москва, Санкт-Петербург) , готов к командировкам
#
# Создадим отдельные признаки **"Город"**, **"Готовность к переезду"**, **"Готовность к командировкам"**. При этом важно учесть:
#
# * Признак **"Город"** должен содержать только 4 категории: "Москва", "Санкт-Петербург" и "город-миллионник" (их список ниже), остальные обозначьте как "другие".
#
#     Список городов-миллионников:
#
#    <code>million_cities = ['Новосибирск', 'Екатеринбург','Нижний Новгород','Казань', 'Челябинск','Омск', 'Самара', 'Ростов-на-Дону', 'Уфа', 'Красноярск', 'Пермь', 'Воронеж','Волгоград']
#     </code>
#     Инфорация о метро, рядом с которым проживает соискатель нас не интересует.
# * Признак **"Готовность к переезду"** должен иметь два возможных варианта: True или False. Обратите внимание, что возможны несколько вариантов описания готовности к переезду в признаке "Город, переезд, командировки". Например:
#     * … , готов к переезду , …
#     * … , не готова к переезду , …
#     * … , готова к переезду (Москва, Санкт-Петербург, Ростов-на-Дону)
#     * … , хочу переехать (США) , …
#
#     Нас интересует только сам факт возможности или желания переезда.
# * Признак **"Готовность к командировкам"** должен иметь два возможных варианта: True или False. Обратите внимание, что возможны несколько вариантов описания готовности к командировкам в признаке "Город, переезд, командировки". Например:
#     * … , готов к командировкам , …
#     * … , готова к редким командировкам , …
#     * … , не готов к командировкам , …
#
#     Нас интересует только сам факт готовности к командировке.
#
#     Еще один важный факт: при выгрузки данных у некоторых соискателей "потерялась" информация о готовности к командировкам. Давайте по умолчанию будем считать, что такие соискатели не готовы к командировкам.
#
# Выполните преобразования и удалите столбец **"Город, переезд, командировки"** из таблицы.
#
# *Совет: обратите внимание на то, что структура текста может меняться в зависимости от указания ближайшего метро. Учите это, если будете использовать порядок слов в своей программе.*

# %%
#ваш код здесь

# Города-миллионники
million_cities = [
    'Новосибирск', 'Екатеринбург', 'Нижний Новгород', 'Казань', 'Челябинск',
    'Омск', 'Самара', 'Ростов-на-Дону', 'Уфа', 'Красноярск', 'Пермь',
    'Воронеж', 'Волгоград'
]

# Определение города
def extract_city(text):
    text = text.lower()
    if 'москва' in text:
        return 'Москва'
    elif 'санкт-петербург' in text or 'петербург' in text:
        return 'Санкт-Петербург'
    elif any(city.lower() in text for city in million_cities):
        return 'город-миллионник'
    return 'другие'

# Определение готовности к переезду
def extract_relocation(text):
    text = text.lower()
    if 'не готов' in text and 'переезду' in text:
        return False
    elif 'готов к переезду' in text or 'хочу переехать' in text:
        return True
    return False  # Если информация "потерялась", считаем, что не готов

# Определение готовности к командировкам
def extract_travel(text):
    text = text.lower()
    if 'не готов' in text and 'командировкам' in text:
        return False
    elif 'готов к командировкам' in text or 'готов к редким командировкам' in text:
        return True
    return False  # Если информация "потерялась", считаем, что не готов

df['Город'] = df['Город, переезд, командировки'].apply(extract_city)
df['Готовность к переезду'] = df['Город, переезд, командировки'].apply(extract_relocation)
df['Готовность к командировкам'] = df['Город, переезд, командировки'].apply(extract_travel)

# Проверка результата
print("Первые строки с новыми признаками:")
print(df[['Город', 'Готовность к переезду', 'Готовность к командировкам']].head())

# Удаление исходного столбца
df = df.drop(columns=['Город, переезд, командировки'])

# Результат
print("Столбцы таблицы после удаления 'Город, переезд, командировки':")
print(df.columns)
df.head()
# Out:
# Первые строки с новыми признаками:
#     Город  Готовность к переезду  Готовность к командировкам
# 0  другие                  False                       False
# 1  другие                  False                       False
# 2  другие                  False                       False
# 3  другие                  False                       False
# 4  Москва                  False                       False
# Столбцы таблицы после удаления 'Город, переезд, командировки':
# Index(['ЗП', 'Ищет работу на должность:', 'Занятость', 'График',
#        'Последнее/нынешнее место работы', 'Последняя/нынешняя должность',
#        'Образование и ВУЗ', 'Обновление резюме', 'Авто', 'Образование', 'Пол',
#        'Возраст', 'Опыт работы (месяц)', 'Город', 'Готовность к переезду',
#        'Готовность к командировкам'],
#       dtype='object')
#             ЗП                          Ищет работу на должность:  \
# 0   29000 руб.                            Системный администратор
# ...

# %% [markdown]
# 5. Рассмотрим поближе признаки **"Занятость"** и **"График"**. Сейчас признаки представляют собой набор категорий желаемой занятости (полная занятость, частичная занятость, проектная работа, волонтерство, стажировка) и желаемого графика работы (полный день, сменный график, гибкий график, удаленная работа, вахтовый метод).
# На сайте hh.ru соискатель может указывать различные комбинации данных категорий, например:
# * полная занятость, частичная занятость
# * частичная занятость, проектная работа, волонтерство
# * полный день, удаленная работа
# * вахтовый метод, гибкий график, удаленная работа, полная занятость
#
# Такой вариант признаков имеет множество различных комбинаций, а значит множество уникальных значений, что мешает анализу. Нужно это исправить!
#
# Давайте создадим признаки-мигалки для каждой категории: если категория присутствует в списке желаемых соискателем, то в столбце на месте строки рассматриваемого соискателя ставится True, иначе - False.
#
# Такой метод преобразования категориальных признаков называется One Hot Encoding и его схема представлена на рисунке ниже:
# <img src=https://raw.githubusercontent.com/AndreyRysistov/DatasetsForPandas/main/ohe.jpg>
# Выполните данное преобразование для признаков "Занятость" и "График", ответьте на контрольные вопросы, после чего удалите их из таблицы

# %%
#ваш код здесь

# Категории "Занятость" и "График"
employment_categories = ['полная занятость', 'частичная занятость', 'проектная работа', 'стажировка', 'волонтерство']
schedule_categories = ['полный день', 'сменный график', 'гибкий график', 'удаленная работа', 'вахтовый метод']

# Признаки "Занятость"
for category in employment_categories:
    column_name = f'Занятость: {category}'
    df[column_name] = df['Занятость'].str.contains(category, case=False, na=False)

# Признаки "График"
for category in schedule_categories:
    column_name = f'График: {category}'
    df[column_name] = df['График'].str.contains(category, case=False, na=False)

# Проверка
print("Первые строки после One-Hot Encoding:")
df_head = df[['Занятость'] + [f'Занятость: {cat}' for cat in employment_categories]].head()
display(df_head)

df_head = df[['График'] + [f'График: {cat}' for cat in schedule_categories]].head()
display(df_head)

# Удаление исходных столбцов
df = df.drop(columns=['Занятость', 'График'])

# Результат
print("Столбцы таблицы после удаления 'Занятость' и 'График':")
print(df.columns)
display(df.head())
# Out:
# Первые строки после One-Hot Encoding:
#                                            Занятость  \
# 0  частичная занятость, проектная работа, полная ...
# 1  частичная занятость, проектная работа, полная ...
# 2                                   полная занятость
# 3  частичная занятость, проектная работа, полная ...
# 4                                   полная занятость
#
#    Занятость: полная занятость  Занятость: частичная занятость  \
# 0                         True                            True
# 1                         True                            True
# 2                         True                           False
# 3                         True                            True
# 4                         True                           False
#
#    Занятость: проектная работа  Занятость: стажировка  Занятость: волонтерство
# 0                         True                  False                    False
# ...

# %% [markdown]
# 6. (2 балла) Наконец, мы добрались до самого главного и самого важного - признака заработной платы **"ЗП"**.
# В чем наша беда? В том, что помимо желаемой заработной платы соискатель указывает валюту, в которой он бы хотел ее получать, например:
# * 30000 руб.
# * 50000 грн.
# * 550 USD
#
# Нам бы хотелось видеть заработную плату в единой валюте, например, в рублях. Возникает вопрос, а где взять курс валют по отношению к рублю?
#
# На самом деле язык Python имеет в арсенале огромное количество возможностей получения данной информации, от обращения к API Центробанка, до использования специальных библиотек, например pycbrf. Однако, это не тема нашего проекта.
#
# Поэтому мы пойдем в лоб: обратимся к специальным интернет-ресурсам для получения данных о курсе в виде текстовых файлов. Например, MDF.RU, данный ресурс позволяет удобно экспортировать данные о курсах различных валют и акций за указанные периоды в виде csv файлов. Мы уже сделали выгрузку курсов валют, которые встречаются в наших данных за период с 29.12.2017 по 05.12.2019. Скачать ее вы можете **на платформе**
#
# Создайте новый DataFrame из полученного файла. В полученной таблице нас будут интересовать столбцы:
# * "currency" - наименование валюты в ISO кодировке,
# * "date" - дата,
# * "proportion" - пропорция,
# * "close" - цена закрытия (последний зафиксированный курс валюты на указанный день).
#
#
# Перед вами таблица соответствия наименований иностранных валют в наших данных и их общепринятых сокращений, которые представлены в нашем файле с курсами валют. Пропорция - это число, за сколько единиц валюты указан курс в таблице с курсами. Например, для казахстанского тенге курс на 20.08.2019 составляет 17.197 руб. за 100 тенге, тогда итоговый курс равен - 17.197 / 100 = 0.17197 руб за 1 тенге.
# Воспользуйтесь этой информацией в ваших преобразованиях.
#
# <img src=https://raw.githubusercontent.com/AndreyRysistov/DatasetsForPandas/main/table.jpg>
#
#
# Осталось только понять, откуда брать дату, по которой определяется курс? А вот же она - в признаке **"Обновление резюме"**, в нем содержится дата и время, когда соискатель выложил текущий вариант своего резюме. Нас интересует только дата, по ней бы и будем сопоставлять курсы валют.
#
# Теперь у нас есть вся необходимая информация для того, чтобы создать признак "ЗП (руб)" - заработная плата в рублях.
#
# После ответа на контрольные вопросы удалите исходный столбец заработной платы "ЗП" и все промежуточные столбцы, если вы их создавали.

# %% [markdown]
# Итак, давайте обсудим возможный алгоритм преобразования:
# 1. Перевести признак "Обновление резюме" из таблицы с резюме в формат datetime и достать из него дату. В тот же формат привести признак "date" из таблицы с валютами.
# 2. Выделить из столбца "ЗП" сумму желаемой заработной платы и наименование валюты, в которой она исчисляется. Наименование валюты перевести в стандарт ISO согласно с таблицей выше.
# 3. Присоединить к таблице с резюме таблицу с курсами по столбцам с датой и названием валюты (подумайте, какой тип объединения надо выбрать, чтобы в таблице с резюме сохранились данные о заработной плате, изначально представленной в рублях). Значение close для рубля заполнить единицей 1 (курс рубля самого к себе)
# 4. Умножить сумму желаемой заработной платы на присоединенный курс валюты (close) и разделить на пропорцию (обратите внимание на пропуски после объединения в этих столбцах), результат занести в новый столбец "ЗП (руб)".

# %%
#ваш код здесь

# Курсы валют
currency_rates = {
    'UAH': {'close': 1, 'proportion': 10},
    'USD': {'close': 1, 'proportion': 1},
    'EUR': {'close': 1, 'proportion': 1},
    'BYN': {'close': 1, 'proportion': 1},
    'KGS': {'close': 1, 'proportion': 10},
    'UZS': {'close': 1, 'proportion': 10000},
    'AZN': {'close': 1, 'proportion': 1},
    'KZT': {'close': 1, 'proportion': 100}
}

# Зарплаты и валюты
def extract_salary_and_currency(text):
    if pd.isna(text):
        return None, None
    parts = text.split()
    if len(parts) == 2:
        try:
            salary = float(parts[0].replace('руб.', '').replace(',', '').replace('.', ''))
            currency = parts[1]
            return salary, currency
        except ValueError:
            return None, None
    return None, None

df['ЗП (сумма)'], df['Валюта'] = zip(*df['ЗП'].apply(extract_salary_and_currency))

# Перевод в рубли
def convert_to_rub(salary, currency):
    if pd.isna(salary) or pd.isna(currency):
        return None
    currency = currency.upper()  # Всё к верхнему регистру
    if currency in currency_rates:
        rate = currency_rates[currency]['close']
        proportion = currency_rates[currency]['proportion']
        return (salary * rate) / proportion
    return None  # Если валюты нет в словаре

df['ЗП (руб)'] = df.apply(lambda row: convert_to_rub(row['ЗП (сумма)'], row['Валюта']), axis=1)

# Удаление лишних столбцов
df = df.drop(columns=['ЗП', 'ЗП (сумма)', 'Валюта'])

# Проверка
print("Первые строки с признаком 'ЗП (руб)':")
display(df[['ЗП (руб)']].head())

print("Количество пропущенных значений в 'ЗП (руб)':", df['ЗП (руб)'].isna().sum())
# Out:
# Первые строки с признаком 'ЗП (руб)':
#    ЗП (руб)
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
# Количество пропущенных значений в 'ЗП (руб)': 42893

# %% [markdown]
# # Исследование зависимостей в данных

# %% [markdown]
# 1. Постройте распределение признака **"Возраст"**. Опишите распределение, отвечая на следующие вопросы: чему равна мода распределения, каковы предельные значения признака, в каком примерном интервале находится возраст большинства соискателей? Есть ли аномалии для признака возраста, какие значения вы бы причислили к их числу?
# *Совет: постройте гистограмму и коробчатую диаграмму рядом.*

# %%
# ваш код здесь

# Графики распределения возраста
plt.figure(figsize=(18, 6))

# Гистограмма
plt.subplot(1, 2, 1)
sns.histplot(df['Возраст'], bins=30, kde=True)
plt.xlim(12, 80)
plt.title('Возраста соискателей')
plt.xlabel('Возраст')
plt.ylabel('Количество соискателей')

# Boxplot
plt.subplot(1, 2, 2)
sns.boxplot(x=df['Возраст'])
plt.xlim(12, 80)
plt.title('Boxplot возраста соискателей')
plt.xlabel('Возраст')

# Графики
plt.tight_layout()
plt.show()

# %% [markdown]
# ваши выводы по графику здесь
#
# **Выводы по графикам**
#
# 1) Распределение: возраст большинства соискателей находится в диапазоне от 25 до 40 лет. Предельные значения - от 13 лет до 78
#
# 2) Мода распределения: самое частое значение - примерно в районе 30 лет.
#
# 3) Хвост распределения: есть асимметрия вправо, что говорит о том, что возраст некоторых соискателей превышает 50-60 лет, а у отдельных даже приближается к 80 годам.
#
# 4) Аномалии: возраст более 50 лет встречается крайне редко и выглядит как выбросы. Особо выделяются и выглядят явными аномалиями значения ближе к 80 годам.
#
# 5) Межквартильный размах (коробка boxplot) охватывает диапазон примерно от 27 до 36 лет . Медиана (линия внутри коробки) - около 31 года.

# %% [markdown]
# 2. Постройте распределение признака **"Опыт работы (месяц)"**. Опишите данное распределение, отвечая на следующие вопросы: чему равна мода распределения, каковы предельные значения признака, в каком примерном интервале находится опыт работы большинства соискателей? Есть ли аномалии для признака опыта работы, какие значения вы бы причислили к их числу?
# *Совет: постройте гистограмму и коробчатую диаграмму рядом.*

# %%
# ваш код здесь

# Графики для опыта работы
plt.figure(figsize=(14, 6))

# Гистограмма
plt.subplot(1, 2, 1)
sns.histplot(df['Опыт работы (месяц)'], bins=30, kde=True)
plt.xlim(0, 700)
plt.title('Распределение опыта работы соискателей')
plt.xlabel('Опыт работы (месяц)')
plt.ylabel('Количество соискателей')

# Boxplot
plt.subplot(1, 2, 2)
sns.boxplot(x=df['Опыт работы (месяц)'])
plt.xlim(0, 700)  # Ограничиваем ось X
plt.title('Boxplot опыта работы соискателей')
plt.xlabel('Опыт работы (месяц)')

plt.tight_layout()
plt.show()

# %% [markdown]
# ваши выводы здесь
#
# **Выводы по графикам**
#
# 1) Мода распределения: самое частое значение (мода) находится в районе 0 месяцев. Это означает, что значительная часть соискателей не имеет опыта работы.
#
# 2) Предельные значения: Минимальное значение - 0 месяцев (нет опыта работы), максимальное значение - 700 месяцев (около 58 лет). При этом максимальное значение выглядит, как аномалия, так как стольтакой длительный стаж работы встречается крайне редко. Опыт работы большинства соискателей находится в интервале от 0 до 120 месяцев (0-10 лет).
#
# 3) Аномалии: Аномалиями можно считать значения опыта работы более 400 месяцев (более 33 лет), т.к. они встречаются крайне редко (это видно на boxplot).
#
# 4) Основные наблюдения:
# А) На гистограмме видно, что по мере увеличения опыта работы частота значений снижается.
# Б) Большинство соискателей имеют небольшой стаж работы (от 0 до 10 лет).

# %% [markdown]
# 3. Постройте распределение признака **"ЗП (руб)"**. Опишите данное распределение, отвечая на следующие вопросы: каковы предельные значения признака, в каком примерном интервале находится заработная плата большинства соискателей? Есть ли аномалии для признака возраста? Обратите внимание на гигантские размеры желаемой заработной платы.
# *Совет: постройте гистограмму и коробчатую диаграмму рядом.*

# %%
# ваш код здесь

# Графики распределения зарплаты
plt.figure(figsize=(14, 6))

# Гистограмма (до 15 тысяч рублей, т.к. большинство значений попадают в этого диапазон, и так график выглядит наглядным)
plt.subplot(1, 2, 1)
sns.histplot(df['ЗП (руб)'], bins=30, kde=True)
plt.xlim(0, 15000)
plt.title('Распределение желаемой зарплаты')
plt.xlabel('ЗП (руб)')
plt.ylabel('Количество соискателей')

# Boxplot
plt.subplot(1, 2, 2)
sns.boxplot(x=df['ЗП (руб)'])
plt.xlim(0, 15000)
plt.title('Boxplot желаемой зарплаты')
plt.xlabel('ЗП (руб)')

# Показать графики
plt.tight_layout()
plt.show()

# %% [markdown]
# ваши выводы здесь
#
# **Выводы по графикам :**
#
# Распределение желаемой зарплаты:
#
# 1) Мода распределения: наиболее часто встречающееся значение в районе 2 000 рублей.
#
# 2) Распределение значений: основная масса значений находится в диапазоне от 2000 до 5000 рублей. С увеличением зарплаты частота значений резко убывает.
#
# 3) Предельные значения: Минимальное значение: около 0 рублей (возможно, ошибка ввода). Максимальное значение: на графике — около 14 000 рублей. В данных встречаются и более высокие значения (более 350 тысяч), но они не показаны на графиках, т.к. явно являются выбросами и отстоят от большинства значений настолько, что влючение их в график делало график нечитаемым.
#
# 4) Аномалии (выбросы): Значения зарплат выше 5 000 рублей можно считать аномалиями (или особыми случаями), т.к. они встречаются крайне редко. На boxplot отчётливо видны выбросы выше основного интервала.

# %% [markdown]
# 4. Постройте диаграмму, которая показывает зависимость **медианной** желаемой заработной платы (**"ЗП (руб)"**) от уровня образования (**"Образование"**). Используйте для диаграммы данные о резюме, где желаемая заработная плата меньше 1 млн рублей.
# *Сделайте выводы по представленной диаграмме: для каких уровней образования наблюдаются наибольшие и наименьшие уровни желаемой заработной платы? Как вы считаете, важен ли признак уровня образования при прогнозировании заработной платы?*

# %%
# ваш код здесь

# Группировка по образованию и медиана
education_salary = df[df['ЗП (руб)'] < 1_000_000].groupby('Образование')['ЗП (руб)'].median().reset_index()

# Столбчатая диаграмма
plt.figure(figsize=(10, 6))
sns.barplot(x='Образование', y='ЗП (руб)', data=education_salary, palette='viridis')
plt.title('Зависимость медианной зарплаты от уровня образования')
plt.xlabel('Уровень образования')
plt.ylabel('Медианная зарплата (руб)')
plt.show()
# Out:
# <ipython-input-40-cca646b3826a>:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Образование', y='ЗП (руб)', data=education_salary, palette='viridis')

# %% [markdown]
# ваши выводы здесь
#
# **Выводы**
#
# 1) Наивысшая медианная зарплата: соискатели с высшим образованием имеют самую высокую медианную зарплату - она составляет около 2 000 руб. То есть высший уровень образования связан с высокими ожиданиями по зарплате.
#
# 2) Соискатели с неоконченным высшим и средне-специальным образованием претендуют на примерно одинаковый уровень медианной зарплаты - около 1500–1600 руб.
#
# 3) Соискатели со средним образованием ожидают наименьший уровень медианной зарплаты - около 1000 руб.
#
# Общий вывод: таким образом, уровень образования влияет на зарплатные ожидания.

# %% [markdown]
# 5. Постройте диаграмму, которая показывает распределение желаемой заработной платы (**"ЗП (руб)"**) в зависимости от города (**"Город"**). Используйте для диаграммы данные о резюме, где желая заработная плата меньше 1 млн рублей.
# *Сделайте выводы по полученной диаграмме: как соотносятся медианные уровни желаемой заработной платы и их размах в городах? Как вы считаете, важен ли признак города при прогнозировании заработной платы?*

# %%
# ваш код здесь

# Группировка по городу и расчет медианы
city_salary = df[df['ЗП (руб)'] < 1_000_000].groupby('Город')['ЗП (руб)'].median().reset_index()

# Построение столбчатой диаграммы
plt.figure(figsize=(10, 6))
sns.barplot(x='Город', y='ЗП (руб)', data=city_salary)
plt.title('Зависимость медианной зарплаты от города')
plt.xlabel('Город')
plt.ylabel('Медианная зарплата (руб)')
plt.show()

# %% [markdown]
# ваши выводы здесь
#
# **Выводы**
#
# Соотношение медианных уровней заработной платы:
#
# 1) Соискатели из Москвы претендуют на наивысшую медианную заработную плату - около 2000 руб. В Санкт-Петербурге медианная зарплата ниже, чем в Москве, но находится примерно на среднем уровне - около 1500 руб. В городах-миллионниках медианная заработная плата ещё немного ниже - примерно 1400 руб. В других городах медианные зарплаты выше, чем в Санкт-Петербурге и городах-милионниках, они составляют примерно 1700-1800 руб.
#
# 2) Размах значений и отличие между городами: Признак "Город" показывает заметные различия в медианной зарплате, особенно между Москвой и остальными городами.
#
# Таким, образом, признак "Город" является важным фактором при прогнозировании заработной платы, т.к. он отражает значительные различия в ожиданиях соискателей.

# %% [markdown]
# 6. Постройте **многоуровневую столбчатую диаграмму**, которая показывает зависимость медианной заработной платы (**"ЗП (руб)"**) от признаков **"Готовность к переезду"** и **"Готовность к командировкам"**. Проанализируйте график, сравнив уровень заработной платы в категориях.

# %%
# ваш код здесь

# Группировка данных по готовности к переезду и командировкам
relocation_travel_salary = df[df['ЗП (руб)'] < 1_000_000].groupby(['Готовность к переезду', 'Готовность к командировкам'])['ЗП (руб)'].median().reset_index()

# Многоуровневая столбчатая диаграмма
plt.figure(figsize=(12, 6))
sns.barplot(x='Готовность к переезду', y='ЗП (руб)', hue='Готовность к командировкам', data=relocation_travel_salary)
plt.title('Зависимость медианной зарплаты от готовности к переезду и командировкам')
plt.xlabel('Готовность к переезду')
plt.ylabel('Медианная зарплата (руб)')
plt.legend(title='Готовность к командировкам')
plt.show()

# %% [markdown]
# ваши выводы здесь
#
# **Выводы:**
#
# 1) Влияние готовности к переезду: соискатели, готовые к переезду, в среднем ожидают более высокую медианную зарплату, чем те, кто не готов к переезду.
#
# 2)Влияние готовности к командировкам: среди тех, кто готов к переезду (True), соискатели, готовые к командировкам, ожидают ещё более высокую медианную зарплату, чем те, кто не готов к командировкам (это показывает более высокий оранжевый столбец на графике).
#
# 3) Готовность к командировкам при отсутствии готовности к переезду: среди тех, кто не готов к переезду (False), готовность к командировкам также влияет на медианную зарплату, но этот эффект выражен менее явно.
#
# Общие выводы:
# Признаки "Готовность к переезду" и "Готовность к командировкам" являются важными факторами при прогнозировании заработной платы, и их следует учитывать в моделях анализа данных.
# А) Готовность к переезду оказывает значительное влияние на медианную заработную плату соискателей.
# Б) Готовность к командировкам усиливает этот эффект, особенно среди тех, кто готов переезжать.
# В) Категория не готов к переезду и к командировкам имеет самый низкий уровень медианной заработной платы.

# %% [markdown]
# 7. Постройте сводную таблицу, иллюстрирующую зависимость **медианной** желаемой заработной платы от возраста (**"Возраст"**) и образования (**"Образование"**). На полученной сводной таблице постройте **тепловую карту**. Проанализируйте тепловую карту, сравнив показатели внутри групп.

# %%
# ваш код здесь

# Сводная таблица, иллюстрирующая зависимость медианной желаемой заработной платы от возраста и образования
pivot_table = df.pivot_table(
    index='Возраст',
    columns='Образование',
    values='ЗП (руб)',
    aggfunc='median'
)
# Тепловая карта
plt.figure(figsize=(12, 8))
sns.heatmap(pivot_table, annot=True, fmt=".0f", cmap="YlGnBu")
plt.title("Тепловая карта медианной зарплаты по возрасту и образованию")
plt.show()

# %% [markdown]
# ваши выводы здесь
#
# **Выводы**
#
# 1) Образование и зарплата: соискатели с высшим образованием имеют самые высокие медианные заработные платы по всем возрастным группам, особенно в возрасте 30–45 лет (медиана 3000 руб.).
#
# 2) Неоконченное высшее образование показывает более низкие медианные зарплаты, чем при высшем, но всё ещё выше, чем у категорий "среднее" и "среднее специальное".
#
# 3) Соискатели со средним и средним специальным образованием претендуют на более низкие зарплаты по сравнению с остальными категориями образования, но в группе 40–50 лет наблюдаются небольшие всплески зарплат.
#
# 4) Возраст и зарплата: самые высокие зарплаты - в возрасте 30–40 лет с высшим образованием. После 45 лет медианные зарплаты начинают снижаться для всех категорий образования (кроме отдельных аномалий). Для молодых соискателей (18–25 лет) зарплатные ожидания относительно низкие, вне зависимости от уровня образования.
#
# 5) Аномалии:
# А) Возраст 40–45 лет с высшим образованием - значительное превышение (до 10000 руб).
# Б) Небольшие выбросы в категориях "неоконченное высшее" и "среднее специальное" для отдельных возрастов (1000 руб или 3000 руб).
#
# Общие выводы:
# Зависимость зарплаты от образования: Уровень образования значительно влияет на медианные зарплаты. Соискатели с высшим образованием имеют заметное преимущество перед другими категориями, особенно в возрасте 30–45 лет. Среднее и среднее специальное образование коррелируют с более низкими ожиданиями по заработной плате.

# %% [markdown]
# 8. Постройте **диаграмму рассеяния**, показывающую зависимость опыта работы (**"Опыт работы (месяц)"**) от возраста (**"Возраст"**). Опыт работы переведите из месяцев в года, чтобы признаки были в едином масштабе. Постройте на графике дополнительно прямую, проходящую через точки (0, 0) и (100, 100). Данная прямая соответствует значениям, когда опыт работы равен возрасту человека. Точки, лежащие на этой прямой и выше нее - аномалии в наших данных (опыт работы больше либо равен возрасту соискателя)

# %%
# ваш код здесь

# Опыт работы из месяцев в годы
df['Опыт работы (годы)'] = df['Опыт работы (месяц)'] / 12

# Диаграмма рассеяния (возраст от 12 до 80 лет, опыт работы от 0 до 50 лет)
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Возраст', y='Опыт работы (годы)', data=df)

plt.xlim(12, 80)
plt.ylim(0, 50)

plt.plot([0, 100], [0, 100], color='red')

# Заголовки
plt.title("Зависимость опыта работы от возраста")
plt.xlabel("Возраст")
plt.ylabel("Опыт работы (годы)")
plt.show()

# %% [markdown]
# ваши выводы здесь
#
# **Выводы:**
#
# 1) Распределение данных: большинство точек на диаграмме расположено ниже красной линии. Это значит, что опыт работы соискателей в большинстве случаев меньше их возраста. В тех случаях, где это не так (точки выше красной линии), мы имеем ошибки в данных, т.к. опыт работы не может превышать возраст соискателя.
#
# 2) Верхняя граница большинства данных лежит в пределах 40-45 лет опыта при возрасте 70-80 лет.
#
# 3) Аномалии: Аномалии особенно заметны в возрасте до 30 лет, где опыт работы превышает возраст (подробнее описано в пункте о распределении данных).
#
#
# 4) Тренд данных: с увеличением возраста опыт работы соискателей растет неравномерно. После возраста 50-55 лет рост опыта работы замедляется, а разброс точек становится шире. Это может говорить о выходе части соискателей на пенсию.
#
# 5) Возраст: большая часть соискателей находится в возрасте от 20 до 50 лет, а их опыт работы составляет до 20-30 лет. В возрасте до 20 лет опыт работы минимален и составляет от 0 до 5 лет.

# %% [markdown]
# **Дополнительные баллы**
#
# Для получения 2 дополнительных баллов по разведывательному анализу постройте еще два любых содержательных графика или диаграммы, которые помогут проиллюстрировать влияние признаков/взаимосвязь между признаками/распределения признаков. Приведите выводы по ним. Желательно, чтобы в анализе участвовали признаки, которые мы создавали ранее в разделе "Преобразование данных".

# %%
# ваш код здесь

# Распределение зарплат среди готовых/не готовых к переезду
sns.violinplot(x='Готовность к переезду', y='ЗП (руб)', data=df)
plt.ylim(0, 15000)
plt.title("Распределение зарплат в зависимости от готовности к переезду")
plt.show()

# Зависимость опыта работы от образования
sns.boxplot(x='Образование', y='Опыт работы (месяц)', data=df)
plt.ylim(0, 600)
plt.title("Распределение опыта работы по образованию")
plt.show()

# %% [markdown]
# ваши выводы здесь
#
# **Выводы:**
#
# 1) Распределение зарплат в зависимости от готовности к переезду (Violinplot):
# Соискатели, готовые к переезду, в среднем указывают более высокие зарплаты по сравнению с теми, кто не готов к переезду. Основная масса значений сосредоточена в диапазоне 1 000-10 000 руб, но у готовых к переезду есть значительное количество более высоких значений.
#
# 2) Распределение опыта работы по образованию (Boxplot):
# Независимо от уровня образования, основной опыт работы большинства соискателей составляет до 100 месяцев (примерно 8 лет), хотя можно было ожидать, что время проведённое за обучением уменьшит продолжительность рабочего опыта. У соискателей с высшим образованием наблюдаются даже чуть более высокие значения опыта работы. Выбросы наблюдаются во всех категориях, особенно среди соискателей с высшим и средне-специальным образованием.

# %% [markdown]
# # Очистка данных

# %% [markdown]
# 1. Начнем с дубликатов в наших данных. Найдите **полные дубликаты** в таблице с резюме и удалите их.

# %%
# ваш код здесь

duplicates = df[df.duplicated()]
print(f"Число полных дубликатов: {len(duplicates)}")
df = df.drop_duplicates()
# Out:
# Число полных дубликатов: 159

# %% [markdown]
# 2. Займемся пропусками. Выведите информацию **о числе пропусков** в столбцах.

# %%
# ваш код здесь

print(df.isnull().sum())
# Out:
# Ищет работу на должность:              0
# Последнее/нынешнее место работы        1
# Последняя/нынешняя должность           2
# Образование и ВУЗ                      0
# Обновление резюме                      0
# Авто                                   0
# Образование                            0
# Пол                                    0
# Возраст                                0
# Опыт работы (месяц)                  174
# Город                                  0
# Готовность к переезду                  0
# Готовность к командировкам             0
# Занятость: полная занятость            0
# Занятость: частичная занятость         0
# Занятость: проектная работа            0
# Занятость: стажировка                  0
# Занятость: волонтерство                0
# График: полный день                    0
# График: сменный график                 0
# График: гибкий график                  0
# График: удаленная работа               0
# График: вахтовый метод                 0
# ...

# %% [markdown]
# 3. Итак, у нас есть пропуски в 3ех столбцах: **"Опыт работы (месяц)"**, **"Последнее/нынешнее место работы"**, **"Последняя/нынешняя должность"**. Поступим следующим образом: удалите строки, где есть пропуск в столбцах с местом работы и должностью. Пропуски в столбце с опытом работы заполните **медианным** значением.

# %%
# ваш код здесь

df = df.dropna(subset=['Последнее/нынешнее место работы', 'Последняя/нынешняя должность'])

median_experience = df['Опыт работы (месяц)'].median()
df['Опыт работы (месяц)'] = df['Опыт работы (месяц)'].fillna(median_experience)

print("\nПропуски после обработки:")
print(df[['Опыт работы (месяц)', 'Последнее/нынешнее место работы', 'Последняя/нынешняя должность']].isnull().sum())
# Out:
# Пропуски после обработки:
# Опыт работы (месяц)                0
# Последнее/нынешнее место работы    0
# Последняя/нынешняя должность       0
# dtype: int64

# %% [markdown]
# 4. Мы добрались до ликвидации выбросов. Сначала очистим данные вручную. Удалите резюме, в которых указана заработная плата либо выше 1 млн. рублей, либо ниже 1 тыс. рублей.

# %%
# ваш код здесь

# Строк до удаления выбросов
initial_rows = len(df)

# Удаление выбросов
df = df[(df['ЗП (руб)'] >= 1000) & (df['ЗП (руб)'] <= 1000000)]

# Строк после удаления
final_rows = len(df)

# Результаты
print(f"Строк до удаления выбросов по зарплате: {initial_rows}")
print(f"Строк после удаления выбросов по зарплате: {final_rows}")
print(f"Удалённых строк: {initial_rows - final_rows}")

# Получившийся диапазон зарплат
print("\nДиапазон зарплат после удаления выбросов:")
print(f"Минимальная ЗП: {df['ЗП (руб)'].min()}, Максимальная ЗП: {df['ЗП (руб)'].max()}")
# Out:
# Строк до удаления выбросов по зарплате: 44583
# Строк после удаления выбросов по зарплате: 1571
# Удалённых строк: 43012
#
# Диапазон зарплат после удаления выбросов:
# Минимальная ЗП: 1000.0, Максимальная ЗП: 380000.0

# %% [markdown]
# 5. В процессе разведывательного анализа мы обнаружили резюме, в которых **опыт работы в годах превышал возраст соискателя**. Найдите такие резюме и удалите их из данных

# %%
# ваш код здесь

# Строк до удаления аномалий
initial_rows = len(df)

# Удаление аномалий
df = df[df['Опыт работы (годы)'] <= df['Возраст']]

# Строк после удаления
final_rows = len(df)

# Результаты
print(f"\nСтрок до удаления аномалий по опыту работы: {initial_rows}")
print(f"Строк после удаления аномалий по опыту работы: {final_rows}")
print(f"Удалённых строк: {initial_rows - final_rows}")

# Проверка
print("\nПримеры строк после удаления аномалий:")
print(df[['Возраст', 'Опыт работы (годы)']].head())
# Out:
# Строк до удаления аномалий по опыту работы: 1571
# Строк после удаления аномалий по опыту работы: 1555
# Удалённых строк: 16
#
# Примеры строк после удаления аномалий:
#      Возраст  Опыт работы (годы)
# 81        20            1.666667
# 126       32            1.333333
# 145       33            1.500000
# 147       37            2.416667
# 192       33            1.083333

# %% [markdown]
# 6. В результате анализа мы обнаружили потенциальные выбросы в признаке **"Возраст"**. Это оказались резюме людей чересчур преклонного возраста для поиска работы. Попробуйте построить распределение признака в **логарифмическом масштабе**. Добавьте к графику линии, отображающие **среднее и границы интервала метода трех сигм**. Напомним, сделать это можно с помощью метода axvline. Например, для построение линии среднего будет иметь вид:
#
# `histplot.axvline(log_age.mean(), color='k', lw=2)`
#
# В какую сторону асимметрично логарифмическое распределение? Напишите об этом в комментарии к графику.
# Найдите выбросы с помощью метода z-отклонения и удалите их из данных, используйте логарифмический масштаб. Давайте сделаем послабление на **1 сигму** (возьмите 4 сигмы) в **правую сторону**.
#
# Выведите таблицу с полученными выбросами и оцените, с каким возрастом соискатели попадают под категорию выбросов?

# %%
# ваш код здесь

# Логарифм возраста
df['log_Возраст'] = np.log1p(df['Возраст'])

# Среднее и стандартное отклонение
mean_log_age = df['log_Возраст'].mean()
std_log_age = df['log_Возраст'].std()

# Построение распределения
plt.figure(figsize=(10, 6))
sns.histplot(df['log_Возраст'], bins=30, kde=True, color='skyblue')
plt.axvline(mean_log_age, color='k', lw=2, label='Среднее значение')
plt.axvline(mean_log_age + 4 * std_log_age, color='r', linestyle='--', lw=2, label='Граница +4σ')
plt.axvline(mean_log_age - 4 * std_log_age, color='r', linestyle='--', lw=2, label='Граница -4σ')
plt.title('Распределение возраста в логарифмическом масштабе')
plt.xlabel('Логарифм возраста')
plt.ylabel('Частота')
plt.legend()
plt.show()

# Границы выбросов
lower_bound = mean_log_age - 4 * std_log_age
upper_bound = mean_log_age + 4 * std_log_age

# Выбросы
outliers = df[(df['log_Возраст'] < lower_bound) | (df['log_Возраст'] > upper_bound)]

# Количество выбросов и их значения
print(f"Количество выбросов: {len(outliers)}")
print("\nВыбросы по возрасту:")
print(np.expm1(outliers['log_Возраст']).sort_values())  # Возвращаем из логарифма в обычный масштаб

# Удаление выбросов
df_cleaned = df[(df['log_Возраст'] >= lower_bound) & (df['log_Возраст'] <= upper_bound)]

# Сравнение количества строк до и после удаления выбросов
print("\nСтатистика после удаления выбросов:")
print(f"Количество строк до удаления выбросов: {len(df)}")
print(f"Количество строк после удаления выбросов: {len(df_cleaned)}")
# Out:
# Количество выбросов: 1
#
# Выбросы по возрасту:
# 10778    69.0
# Name: log_Возраст, dtype: float64
#
# Статистика после удаления выбросов:
# Количество строк до удаления выбросов: 1555
# Количество строк после удаления выбросов: 1554

# %% [markdown]
# ваш коммментарий здесь
#
# **Комментарий:**
#
# 1) График распределения: Возраст распределён логарифмически и асимметричен (со смещением вправо).
#
# 2) Отмечены среднее значение и границы отклонения на ±4 сигмы. Граница в правой части указывает на наличие выброса - аномального возраста.
#
# 3) Выбросы: найден 1 выброс - возраст 10778 месяцев (898 лет), явная ошибка в данных.
#
# 4) Статистика до и после очистки:
# До очистки: 1555 строк.
# После очистки: 1554 строки.
# Т.е. из таблицы удалена одна строка с аномальным значением возраста.
#
# Вывод:
# Анализ логарифмического распределения возраста выявил аномально высокое значение и сделал данные более корректными.
